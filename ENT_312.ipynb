# %% [markdown]
# <a href="https://colab.research.google.com/github/babatundemonsurat2020-spec/for-my-assignment-/blob/main/ENT_312.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# c = 39
# a = 39
# d = 0
# e = 4.333333333333333
# g = 351
# h = 351
# I = 4

# %%
In(): Name=Babatunde monsurat kikelomo
# Out:
#   File "/tmp/ipykernel_2168/1678518035.py", line 1
#     In(): Name=Babatunde monsurat kikelomo
#     ^
# SyntaxError: illegal target for annotation

# %%
)
# Out:
# Babatunde monsurat kikelomo
# Babatunde monsurat kikelomo

# %%
print("a=30,b=9,c=a+b"),a=a+b ,print(d),e=a/b,print(c),g=a*b,print (a),h=a*b,print(g),I=a//b print ")
# Out:
#   File "/tmp/ipykernel_8151/3341309301.py", line 1
#     print("a=30,b=9,c=a+b"),a=a+b ,print(d),e=a/b,print(c),g=a*b,print (a),h=a*b,print(g),I=a//b print ")
#                                                                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# Out:
#   File "/tmp/ipykernel_2168/668226705.py", line 1
#     Name Babatunde monsurat kikelomo.
#          ^
# SyntaxError: invalid syntax

# %%
Address=print ("13 Olohunda compound Asa dam road Ilorin")
# Out:
# 13 Olohunda compound Asa dam road Ilorin

# %%
Print (type(45×6.5)
# Out:
#   File "/tmp/ipykernel_2073/1726509935.py", line 1
#     Print (type(45×6.5)
#                   ^
# SyntaxError: invalid character '×' (U+00D7)

# %%
 Name("mustapha Mukaila")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2073/3594795715.py in <cell line: 0>()
# ----> 1 Name("mustapha Mukaila")
#
# TypeError: 'NoneType' object is not callable

# %%
Print("type name")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2073/2226565167.py in <cell line: 0>()
# ----> 1 Print("type name")
#
# NameError: name 'Print' is not defined

# %%
Print (

# %%
type a=30
